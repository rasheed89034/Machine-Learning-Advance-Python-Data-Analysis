# %% [markdown]
# ## Reading Data From Different Sources

# %%
import pandas as pd
from io import StringIO
data = '''
[
    {"Employee Name" : "Rasheed Ahmad","Age" : 20,"Job Title": "ML Engineer"},
    {"Employee Name" : "Muhammda Ahmad","Age" : 23,"Job Title": "App Developer"}
]'''
df = pd.read_json(StringIO(data))
df
# Out:
#     Employee Name  Age      Job Title
# 0   Rasheed Ahmad   20    ML Engineer
# 1  Muhammda Ahmad   23  App Developer

# %%
df.to_json()
# Out:
# '{"Employee Name":{"0":"Rasheed Ahmad","1":"Muhammda Ahmad"},"Age":{"0":20,"1":23},"Job Title":{"0":"ML Engineer","1":"App Developer"}}'

# %%
json_recorde = df.to_json(orient='records')
json_recorde
# Out:
# '[{"Employee Name":"Rasheed Ahmad","Age":20,"Job Title":"ML Engineer"},{"Employee Name":"Muhammda Ahmad","Age":23,"Job Title":"App Developer"}]'

# %%
df = pd.read_csv("chaska_cafe_sales_data.csv",header=None)
df.head()
# Out:
#             0            1                   2      3
# 0        Date     Category                Item  Sales
# 1  01/01/2023  Veg Burgers  Classic Veg Burger     32
# 2  01/01/2023  Veg Burgers   Cheese Veg Burger     31
# 3  01/01/2023  Veg Burgers    Spicy Veg Burger     18
# 4  01/01/2023  Veg Burgers   Aloo Tikki Burger     47

# %%
df.to_csv("wine.csv")

# %%
# !pip install lxml

# %%
# !pip install html5lib

# %%
# !pip install beautifulsoup4

# %%
url = "https://www.fdic.gov/bank-failures/failed-bank-list"
pd.read_html(url)
# Out:
# [                                            Bank Name                City  \
#  0                        The Santa Anna National Bank          Santa Anna
#  1                                Pulaski Savings Bank             Chicago
#  2                  The First National Bank of Lindsay             Lindsay
#  3               Republic First Bank dba Republic Bank        Philadelphia
#  4                                       Citizens Bank            Sac City
#  5                            Heartland Tri-State Bank             Elkhart
#  6                                 First Republic Bank       San Francisco
#  7                                      Signature Bank            New York
#  8                                 Silicon Valley Bank         Santa Clara
#  9                                   Almena State Bank              Almena
#  10                         First City Bank of Florida   Fort Walton Beach
# ...

# %%
df[0]
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...

# %%
excelData = pd.read_excel("Book1.xlsx")
excelData
# Out:
#             Name  Age
# 0  Rasheed Ahmad   20
# 1          Jamal   20
# 2       Ali khan   21

# %%
excelData.to_pickle('excelData')
pd.read_pickle('excelData')
# Out:
#             Name  Age
# 0  Rasheed Ahmad   20
# 1          Jamal   20
# 2       Ali khan   21
